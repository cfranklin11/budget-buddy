# %%
import pandas as pd
import os
import re
import numpy as np

# Load the raw Excel file
file_name = 'Department-of-Economic-Development-Jobs-Transport-and-Resources-Output-Performance-Measures-2017-18.xlsx'
file_path = os.path.abspath(os.path.join(os.getcwd(), '../raw_data/budgets/', file_name))
data = pd.read_excel(file_path, header=None, thousands=' ')

data
# Out:
#                                                     0                1   \
# 0    Department of Economic Development, Jobs, Tran...              NaN
# 1                                                  NaN              NaN
# 2                           Major Outputs/Deliverables  Unit of measure
# 3                                 Performance measures              NaN
# 4    More productive, competitive, sustainable and ...              NaN
# 5    The objective creates the conditions for and s...              NaN
# 6                                          Agriculture              NaN
# 7    This output delivers effective and efficient r...              NaN
# 8                                             Quantity              NaN
# 9    Animal pest, disease and residue control progr...           number
# 10   Applications for intellectual property protection           number
# 11       Client interactions with land health services           number
# 12   The lower 2017-18 target reflects seasonal con...              NaN
# 13   Clients engaged with agriculture productivity ...           number
# 14   Commercial technology licence agreements final...           number
# 15   Farms and related small businesses facing sign...           number
# 16   Genetic improvement of dairy cows achieved thr...         per cent
# 17   Improved agricultural productivity services, p...           number
# 18   Inspections or audits of scientific establishm...           number
# 19   The 2016 17 expected outcome is lower than the...              NaN
# 20    Key bioscience platform technologies established           number
# 21   Known state prohibited weed sites monitored an...         per cent
# 22   New or amended Interstate Certificate Assuranc...           number
# 23   Plant pest, disease and residue control progra...           number
# 24   Projects delivered to support community led ma...           number
# 25   This performance measure is proposed to replac...              NaN
# 26        Post-graduate level/PhD students in training           number
# 27   Strategies developed to overcome identified tr...           number
# 28   Value of co-investment from external (non-stat...        $ million
# 29                                             Quality              NaN
# ..                                                 ...              ...
# 636  Compliance inspections of managed and unmanage...         per cent
# 637  This performance measures replaces the 2016-17...              NaN
# 638  Deliver regulatory services under delegation o...         per cent
# 639  This performance measure renames the existing ...              NaN
# 640  Rail safety audits, compliance inspections and...         per cent
# 641  This performance measure was proposed to be di...              NaN
# 642  Road safety projects completed within agreed s...         per cent
# 643  Road vehicle and driver regulation: currency o...         per cent
# 644  Road vehicle and driver regulation: user satis...         per cent
# 645  The higher 2016-17 expected outcome is a resul...              NaN
# 646                                         Timeliness              NaN
# 647  Applications for bus operator registration and...         per cent
# 648  Applications for rail accreditation and variat...         per cent
# 649  Initiate marine pollution response action with...         per cent
# 650  Multi Purpose Taxi Program: applications asses...         per cent
# 651  New and renewed taxi, hire vehicle and bus dri...         per cent
# 652  This performance measure amends the 2016-17 pe...              NaN
# 653  Road safety programmed works completed within ...         per cent
# 654  Road vehicle and driver regulation: average sp...          seconds
# 655  The 2016-17 expected outcome is higher than th...              NaN
# 656  Road vehicle and driver regulation: customers ...         per cent
# 657  Road vehicle and driver regulation: new and re...         per cent
# 658  This performance measure was proposed to be di...              NaN
# 659  Taxi, hire vehicles and other commercial passe...         per cent
# 660  Transport and marine safety investigations: ac...         per cent
# 661  Transport and marine safety investigations: av...           months
# 662                                               Cost              NaN
# 663                                  Total output cost        $ million
# 664  The 2016-17 expected outcome is lower than the...              NaN
# 665  Source: Department of Economic Development, Jo...              NaN
#
#                  2                         3               4               5   \
# 0               NaN                       NaN             NaN             NaN
# 1               NaN                       NaN             NaN             NaN
# 2    2017-18 target  2016-17 expected outcome  2016-17 target  2015-16 actual
# 3               NaN                       NaN             NaN             NaN
# 4               NaN                       NaN             NaN             NaN
# 5               NaN                       NaN             NaN             NaN
# 6               NaN                       NaN             NaN             NaN
# 7               NaN                       NaN             NaN             NaN
# 8               NaN                       NaN             NaN             NaN
# 9                 5                         5               5               5
# 10               16                        16              16              16
# 11             1700                      3400            3500            3858
# 12              NaN                       NaN             NaN             NaN
# 13             3910                      3910            3910            5078
# 14               16                        16              16              16
# 15             1700                      1700            1700            1700
# 16                1                         1               1               1
# 17               10                        10              10              10
# 18               25                        23              25              17
# 19              NaN                       NaN             NaN             NaN
# 20                1                         1               1               2
# 21               90                        90              90              99
# 22                2                         2               2               4
# 23                6                         6               6               6
# 24               25                        nm              nm              nm
# 25              NaN                       NaN             NaN             NaN
# 26               65                        65              65              77
# 27                7                         7               7               7
# 28               36                        36              36              38
# 29              NaN                       NaN             NaN             NaN
# ..              ...                       ...             ...             ...
# 636             100                        nm              nm              nm
# 637             NaN                       NaN             NaN             NaN
# 638             100                       100             100             100
# 639             NaN                       NaN             NaN             NaN
# 640             100                       100             100             100
# 641             NaN                       NaN             NaN             NaN
# 642             100                       100             100             100
# 643              99                        99              99              99
# 644              85                        91             >85              90
# 645             NaN                       NaN             NaN             NaN
# 646             NaN                       NaN             NaN             NaN
# 647             100                       100             100             100
# 648             100                       100             100             100
# 649             100                       100             100             100
# 650              97                        97              97              99
# 651              85                        85              85              70
# 652             NaN                       NaN             NaN             NaN
# 653             100                       100             100             100
# 654             240                       290             240             268
# 655             NaN                       NaN             NaN             NaN
# 656              80                        80              80              76
# 657              85                        85              85              88
# 658             NaN                       NaN             NaN             NaN
# 659              85                        85              85              nm
# 660             100                       100             100             100
# 661              12                        12              12              16
# 662             NaN                       NaN             NaN             NaN
# 663           363.9                     331.3           354.1           286.8
# 664             NaN                       NaN             NaN             NaN
# 665             NaN                       NaN             NaN             NaN
#
#                  6               7               8               9   ...    \
# 0               NaN             NaN             NaN             NaN  ...
# 1               NaN             NaN             NaN             NaN  ...
# 2    2015-16 target  2014-15 actual  2014-15 target  2013-14 actual  ...
# 3               NaN             NaN             NaN             NaN  ...
# 4               NaN             NaN             NaN             NaN  ...
# 5               NaN             NaN             NaN             NaN  ...
# 6               NaN             NaN             NaN             NaN  ...
# 7               NaN             NaN             NaN             NaN  ...
# 8               NaN             NaN             NaN             NaN  ...
# 9                 5               5               5               5  ...
# 10               16               8               8               7  ...
# 11             1700              nm              nm              nm  ...
# 12              NaN             NaN             NaN             NaN  ...
# 13             5100            5464           5 500              nm  ...
# 14               16              16              16              16  ...
# 15             1700            1669           2 000            1893  ...
# 16                1               1               1               1  ...
# 17               10               8               8              nm  ...
# 18               25              25              25              25  ...
# 19              NaN             NaN             NaN             NaN  ...
# 20                1               3               1               1  ...
# 21               90              90              90              90  ...
# 22                2              nm              nm              nm  ...
# 23                6               6               6               6  ...
# 24               nm              nm              nm              nm  ...
# 25              NaN             NaN             NaN             NaN  ...
# 26               65              65              65              68  ...
# 27                7               7               7               3  ...
# 28               36              45              36            41.5  ...
# 29              NaN             NaN             NaN             NaN  ...
# ..              ...             ...             ...             ...  ...
# 636              nm              nm              nm              nm  ...
# 637             NaN             NaN             NaN             NaN  ...
# 638             100             100             100             100  ...
# 639             NaN             NaN             NaN             NaN  ...
# 640             100              nm              nm              nm  ...
# 641             NaN             NaN             NaN             NaN  ...
# 642             100             100             100             100  ...
# 643              99              99              99              99  ...
# 644             >85              89             >85             >91  ...
# 645             NaN             NaN             NaN             NaN  ...
# 646             NaN             NaN             NaN             NaN  ...
# 647             100             100             100              nm  ...
# 648             100             100             100             100  ...
# 649             100             100             100             100  ...
# 650              97              99              96            98.5  ...
# 651              85              50              85            80.8  ...
# 652             NaN             NaN             NaN             NaN  ...
# 653             100             100             100             100  ...
# 654             240             208             240             202  ...
# 655             NaN             NaN             NaN             NaN  ...
# 656              80              81              80              80  ...
# 657              85              75              85            86.3  ...
# 658             NaN             NaN             NaN             NaN  ...
# 659              nm              nm              nm              nm  ...
# 660             100             100             100             100  ...
# 661              12              14              12              12  ...
# 662             NaN             NaN             NaN             NaN  ...
# 663           326.7           280.3           301.1           274.2  ...
# 664             NaN             NaN             NaN             NaN  ...
# 665             NaN             NaN             NaN             NaN  ...
#
#                  13              14              15              16  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2    2011-12 actual  2011-12 target  2010-11 actual  2010-11 target
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# 5               NaN             NaN             NaN             NaN
# 6               NaN             NaN             NaN             NaN
# 7               NaN             NaN             NaN             NaN
# 8               NaN             NaN             NaN             NaN
# 9                 5               5              5                5
# 10               12               8               8               8
# 11               nm              nm              nm              nm
# 12              NaN             NaN             NaN             NaN
# 13               nm              nm              nm              nm
# 14               25              20              16              20
# 15            1 779           2 000           1 889            1800
# 16                1               1               1               1
# 17               nm              nm              nm              nm
# 18               nm              nm              nm              nm
# 19              NaN             NaN             NaN             NaN
# 20                2               2               3               2
# 21               96              95              97              95
# 22               nm              nm              nm              nm
# 23                5               6               5               6
# 24               nm              nm              nm              nm
# 25              NaN             NaN             NaN             NaN
# 26               87              64             97               77
# 27                3               3               3               3
# 28             51.5            40.5            52.9              37
# 29              NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 636              nm              nm              nm              nm
# 637             NaN             NaN             NaN             NaN
# 638              99             100              99             100
# 639             NaN             NaN             NaN             NaN
# 640              nm              nm              nm              nm
# 641             NaN             NaN             NaN             NaN
# 642             100             100             100             100
# 643              99              99              99              99
# 644              89             >85              90             >85
# 645             NaN             NaN             NaN             NaN
# 646             NaN             NaN             NaN             NaN
# 647              nm              nm              nm              nm
# 648             100             100             100             100
# 649             100             100              nm              nm
# 650            96.5              95              98              90
# 651              nm              nm              nm              nm
# 652             NaN             NaN             NaN             NaN
# 653             100             100              76             100
# 654              nm              80              49              80
# 655             NaN             NaN             NaN             NaN
# 656              71              80              69              80
# 657              nm              nm              nm              nm
# 658             NaN             NaN             NaN             NaN
# 659              nm              nm              nm              nm
# 660             100             100             100             100
# 661              nm              nm              nm              nm
# 662             NaN             NaN             NaN             NaN
# 663             100           101.5           118.8              nm
# 664             NaN             NaN             NaN             NaN
# 665             NaN             NaN             NaN             NaN
#
#                  17              18              19              20  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2    2009-10 actual  2009-10 target  2008-09 actual  2008-09 target
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# 5               NaN             NaN             NaN             NaN
# 6               NaN             NaN             NaN             NaN
# 7               NaN             NaN             NaN             NaN
# 8               NaN             NaN             NaN             NaN
# 9                 5               5               5               5
# 10               12               6              12              10
# 11               nm              nm              nm              nm
# 12              NaN             NaN             NaN             NaN
# 13               nm              nm              nm              nm
# 14               28              20              nm              nm
# 15             2060           1 800              nm              nm
# 16                1               1               1               1
# 17               nm              nm              nm              nm
# 18               nm              nm              nm              nm
# 19              NaN             NaN             NaN             NaN
# 20                2               2               2               2
# 21               98              95              nm              nm
# 22               nm              nm              nm              nm
# 23                6               6               6               6
# 24               nm              nm              nm              nm
# 25              NaN             NaN             NaN             NaN
# 26              100              77              83              30
# 27                3               3               3               3
# 28             54.6              38            44.1            37.2
# 29              NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 636              nm              nm              nm              nm
# 637             NaN             NaN             NaN             NaN
# 638             100             100              95             100
# 639             NaN             NaN             NaN             NaN
# 640              nm              nm              nm              nm
# 641             NaN             NaN             NaN             NaN
# 642             100             100             100             100
# 643              99             >99              99             >99
# 644              91             >85              93             >85
# 645             NaN             NaN             NaN             NaN
# 646             NaN             NaN             NaN             NaN
# 647              nm              nm              nm              nm
# 648              97             100             100             100
# 649              nm              nm              nm              nm
# 650              88              90              93              80
# 651              nm              nm              nm              nm
# 652             NaN             NaN             NaN             NaN
# 653              78             100             100             100
# 654              65              80              69              80
# 655             NaN             NaN             NaN             NaN
# 656              68              80              68              80
# 657              nm              nm              nm              nm
# 658             NaN             NaN             NaN             NaN
# 659              nm              nm              nm              nm
# 660             100             100             100             100
# 661              nm              nm              nm              nm
# 662             NaN             NaN             NaN             NaN
# 663              nm              nm              nm              nm
# 664             NaN             NaN             NaN             NaN
# 665             NaN             NaN             NaN             NaN
#
#                  21     22
# 0               NaN    NaN
# 1               NaN    NaN
# 2    2007-08 actual  Notes
# 3               NaN    NaN
# 4               NaN    NaN
# 5               NaN    NaN
# 6               NaN    NaN
# 7               NaN    NaN
# 8               NaN    NaN
# 9                 5    NaN
# 10               11    NaN
# 11               nm    NaN
# 12              NaN    NaN
# 13               nm    NaN
# 14               nm    NaN
# 15               nm    NaN
# 16               nm    NaN
# 17               nm    NaN
# 18               nm    NaN
# 19              NaN    NaN
# 20               nm    NaN
# 21               nm    NaN
# 22               nm    NaN
# 23                6    NaN
# 24               nm    NaN
# 25              NaN    NaN
# 26               nm    NaN
# 27                7    NaN
# 28             34.3    NaN
# 29              NaN    NaN
# ..              ...    ...
# 636              nm    NaN
# 637             NaN    NaN
# 638            96.4    NaN
# 639             NaN    NaN
# 640              nm    NaN
# 641             NaN    NaN
# 642             100    NaN
# 643              99    NaN
# 644              na    NaN
# 645             NaN    NaN
# 646             NaN    NaN
# 647              nm    NaN
# 648              nm    NaN
# 649              nm    NaN
# 650              53    NaN
# 651              nm    NaN
# 652             NaN    NaN
# 653             100    NaN
# 654              48    NaN
# 655             NaN    NaN
# 656              70    NaN
# 657              nm    NaN
# 658             NaN    NaN
# 659              nm    NaN
# 660             100    NaN
# 661              nm    NaN
# 662             NaN    NaN
# 663              nm    NaN
# 664             NaN    NaN
# 665             NaN    NaN
#
# [666 rows x 23 columns]

# %%
# Clean up the numbers
character_regex = re.compile('[\s,<>]')

def converter(cell_value):
    if type(cell_value) == str:
        # 'nm' is the VIC government's NaN
        if cell_value == 'nm':
            return np.nan

        # Some numbers are presented as ranges with '-'. We just average the range to get a useable value.
        if '-' in cell_value:
            numbers = cell_value.split('-')

            try:
                return np.mean(float(numbers[0]), float(numbers[1]))
            except (ValueError, TypeError):
                return cell_value

        # Remove spaces and symbols
        if bool(re.search(character_regex, cell_value)):
            number = re.sub(character_regex, '', cell_value)
            
            try:
                return float(number)
            except ValueError:
                return cell_value

    return cell_value

data = data.applymap(lambda x: converter(x))

data
# Out:
#                                                     0                1   \
# 0    Department of Economic Development, Jobs, Tran...              NaN
# 1                                                  NaN              NaN
# 2                           Major Outputs/Deliverables  Unit of measure
# 3                                 Performance measures              NaN
# 4    More productive, competitive, sustainable and ...              NaN
# 5    The objective creates the conditions for and s...              NaN
# 6                                          Agriculture              NaN
# 7    This output delivers effective and efficient r...              NaN
# 8                                             Quantity              NaN
# 9    Animal pest, disease and residue control progr...           number
# 10   Applications for intellectual property protection           number
# 11       Client interactions with land health services           number
# 12   The lower 2017-18 target reflects seasonal con...              NaN
# 13   Clients engaged with agriculture productivity ...           number
# 14   Commercial technology licence agreements final...           number
# 15   Farms and related small businesses facing sign...           number
# 16   Genetic improvement of dairy cows achieved thr...         per cent
# 17   Improved agricultural productivity services, p...           number
# 18   Inspections or audits of scientific establishm...           number
# 19   The 2016 17 expected outcome is lower than the...              NaN
# 20    Key bioscience platform technologies established           number
# 21   Known state prohibited weed sites monitored an...         per cent
# 22   New or amended Interstate Certificate Assuranc...           number
# 23   Plant pest, disease and residue control progra...           number
# 24   Projects delivered to support community led ma...           number
# 25   This performance measure is proposed to replac...              NaN
# 26        Post-graduate level/PhD students in training           number
# 27   Strategies developed to overcome identified tr...           number
# 28   Value of co-investment from external (non-stat...        $ million
# 29                                             Quality              NaN
# ..                                                 ...              ...
# 636  Compliance inspections of managed and unmanage...         per cent
# 637  This performance measures replaces the 2016-17...              NaN
# 638  Deliver regulatory services under delegation o...         per cent
# 639  This performance measure renames the existing ...              NaN
# 640  Rail safety audits, compliance inspections and...         per cent
# 641  This performance measure was proposed to be di...              NaN
# 642  Road safety projects completed within agreed s...         per cent
# 643  Road vehicle and driver regulation: currency o...         per cent
# 644  Road vehicle and driver regulation: user satis...         per cent
# 645  The higher 2016-17 expected outcome is a resul...              NaN
# 646                                         Timeliness              NaN
# 647  Applications for bus operator registration and...         per cent
# 648  Applications for rail accreditation and variat...         per cent
# 649  Initiate marine pollution response action with...         per cent
# 650  Multi Purpose Taxi Program: applications asses...         per cent
# 651  New and renewed taxi, hire vehicle and bus dri...         per cent
# 652  This performance measure amends the 2016-17 pe...              NaN
# 653  Road safety programmed works completed within ...         per cent
# 654  Road vehicle and driver regulation: average sp...          seconds
# 655  The 2016-17 expected outcome is higher than th...              NaN
# 656  Road vehicle and driver regulation: customers ...         per cent
# 657  Road vehicle and driver regulation: new and re...         per cent
# 658  This performance measure was proposed to be di...              NaN
# 659  Taxi, hire vehicles and other commercial passe...         per cent
# 660  Transport and marine safety investigations: ac...         per cent
# 661  Transport and marine safety investigations: av...           months
# 662                                               Cost              NaN
# 663                                  Total output cost        $ million
# 664  The 2016-17 expected outcome is lower than the...              NaN
# 665  Source: Department of Economic Development, Jo...              NaN
#
#                  2                         3               4               5   \
# 0               NaN                       NaN             NaN             NaN
# 1               NaN                       NaN             NaN             NaN
# 2    2017-18 target  2016-17 expected outcome  2016-17 target  2015-16 actual
# 3               NaN                       NaN             NaN             NaN
# 4               NaN                       NaN             NaN             NaN
# 5               NaN                       NaN             NaN             NaN
# 6               NaN                       NaN             NaN             NaN
# 7               NaN                       NaN             NaN             NaN
# 8               NaN                       NaN             NaN             NaN
# 9                 5                         5               5               5
# 10               16                        16              16              16
# 11             1700                      3400            3500            3858
# 12              NaN                       NaN             NaN             NaN
# 13             3910                      3910            3910            5078
# 14               16                        16              16              16
# 15             1700                      1700            1700            1700
# 16                1                         1               1               1
# 17               10                        10              10              10
# 18               25                        23              25              17
# 19              NaN                       NaN             NaN             NaN
# 20                1                         1               1               2
# 21               90                        90              90              99
# 22                2                         2               2               4
# 23                6                         6               6               6
# 24               25                       NaN             NaN             NaN
# 25              NaN                       NaN             NaN             NaN
# 26               65                        65              65              77
# 27                7                         7               7               7
# 28               36                        36              36              38
# 29              NaN                       NaN             NaN             NaN
# ..              ...                       ...             ...             ...
# 636             100                       NaN             NaN             NaN
# 637             NaN                       NaN             NaN             NaN
# 638             100                       100             100             100
# 639             NaN                       NaN             NaN             NaN
# 640             100                       100             100             100
# 641             NaN                       NaN             NaN             NaN
# 642             100                       100             100             100
# 643              99                        99              99              99
# 644              85                        91              85              90
# 645             NaN                       NaN             NaN             NaN
# 646             NaN                       NaN             NaN             NaN
# 647             100                       100             100             100
# 648             100                       100             100             100
# 649             100                       100             100             100
# 650              97                        97              97              99
# 651              85                        85              85              70
# 652             NaN                       NaN             NaN             NaN
# 653             100                       100             100             100
# 654             240                       290             240             268
# 655             NaN                       NaN             NaN             NaN
# 656              80                        80              80              76
# 657              85                        85              85              88
# 658             NaN                       NaN             NaN             NaN
# 659              85                        85              85             NaN
# 660             100                       100             100             100
# 661              12                        12              12              16
# 662             NaN                       NaN             NaN             NaN
# 663           363.9                     331.3           354.1           286.8
# 664             NaN                       NaN             NaN             NaN
# 665             NaN                       NaN             NaN             NaN
#
#                  6               7               8               9   ...    \
# 0               NaN             NaN             NaN             NaN  ...
# 1               NaN             NaN             NaN             NaN  ...
# 2    2015-16 target  2014-15 actual  2014-15 target  2013-14 actual  ...
# 3               NaN             NaN             NaN             NaN  ...
# 4               NaN             NaN             NaN             NaN  ...
# 5               NaN             NaN             NaN             NaN  ...
# 6               NaN             NaN             NaN             NaN  ...
# 7               NaN             NaN             NaN             NaN  ...
# 8               NaN             NaN             NaN             NaN  ...
# 9                 5               5               5               5  ...
# 10               16               8               8               7  ...
# 11             1700             NaN             NaN             NaN  ...
# 12              NaN             NaN             NaN             NaN  ...
# 13             5100            5464            5500             NaN  ...
# 14               16              16              16              16  ...
# 15             1700            1669            2000            1893  ...
# 16                1               1               1               1  ...
# 17               10               8               8             NaN  ...
# 18               25              25              25              25  ...
# 19              NaN             NaN             NaN             NaN  ...
# 20                1               3               1               1  ...
# 21               90              90              90              90  ...
# 22                2             NaN             NaN             NaN  ...
# 23                6               6               6               6  ...
# 24              NaN             NaN             NaN             NaN  ...
# 25              NaN             NaN             NaN             NaN  ...
# 26               65              65              65              68  ...
# 27                7               7               7               3  ...
# 28               36              45              36            41.5  ...
# 29              NaN             NaN             NaN             NaN  ...
# ..              ...             ...             ...             ...  ...
# 636             NaN             NaN             NaN             NaN  ...
# 637             NaN             NaN             NaN             NaN  ...
# 638             100             100             100             100  ...
# 639             NaN             NaN             NaN             NaN  ...
# 640             100             NaN             NaN             NaN  ...
# 641             NaN             NaN             NaN             NaN  ...
# 642             100             100             100             100  ...
# 643              99              99              99              99  ...
# 644              85              89              85              91  ...
# 645             NaN             NaN             NaN             NaN  ...
# 646             NaN             NaN             NaN             NaN  ...
# 647             100             100             100             NaN  ...
# 648             100             100             100             100  ...
# 649             100             100             100             100  ...
# 650              97              99              96            98.5  ...
# 651              85              50              85            80.8  ...
# 652             NaN             NaN             NaN             NaN  ...
# 653             100             100             100             100  ...
# 654             240             208             240             202  ...
# 655             NaN             NaN             NaN             NaN  ...
# 656              80              81              80              80  ...
# 657              85              75              85            86.3  ...
# 658             NaN             NaN             NaN             NaN  ...
# 659             NaN             NaN             NaN             NaN  ...
# 660             100             100             100             100  ...
# 661              12              14              12              12  ...
# 662             NaN             NaN             NaN             NaN  ...
# 663           326.7           280.3           301.1           274.2  ...
# 664             NaN             NaN             NaN             NaN  ...
# 665             NaN             NaN             NaN             NaN  ...
#
#                  13              14              15              16  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2    2011-12 actual  2011-12 target  2010-11 actual  2010-11 target
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# 5               NaN             NaN             NaN             NaN
# 6               NaN             NaN             NaN             NaN
# 7               NaN             NaN             NaN             NaN
# 8               NaN             NaN             NaN             NaN
# 9                 5               5               5               5
# 10               12               8               8               8
# 11              NaN             NaN             NaN             NaN
# 12              NaN             NaN             NaN             NaN
# 13              NaN             NaN             NaN             NaN
# 14               25              20              16              20
# 15             1779            2000            1889            1800
# 16                1               1               1               1
# 17              NaN             NaN             NaN             NaN
# 18              NaN             NaN             NaN             NaN
# 19              NaN             NaN             NaN             NaN
# 20                2               2               3               2
# 21               96              95              97              95
# 22              NaN             NaN             NaN             NaN
# 23                5               6               5               6
# 24              NaN             NaN             NaN             NaN
# 25              NaN             NaN             NaN             NaN
# 26               87              64              97              77
# 27                3               3               3               3
# 28             51.5            40.5            52.9              37
# 29              NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 636             NaN             NaN             NaN             NaN
# 637             NaN             NaN             NaN             NaN
# 638              99             100              99             100
# 639             NaN             NaN             NaN             NaN
# 640             NaN             NaN             NaN             NaN
# 641             NaN             NaN             NaN             NaN
# 642             100             100             100             100
# 643              99              99              99              99
# 644              89              85              90              85
# 645             NaN             NaN             NaN             NaN
# 646             NaN             NaN             NaN             NaN
# 647             NaN             NaN             NaN             NaN
# 648             100             100             100             100
# 649             100             100             NaN             NaN
# 650            96.5              95              98              90
# 651             NaN              nm             NaN             NaN
# 652             NaN             NaN             NaN             NaN
# 653             100             100              76             100
# 654             NaN              80              49              80
# 655             NaN             NaN             NaN             NaN
# 656              71              80              69              80
# 657             NaN             NaN             NaN             NaN
# 658             NaN             NaN             NaN             NaN
# 659             NaN             NaN             NaN             NaN
# 660             100             100             100             100
# 661             NaN              nm             NaN             NaN
# 662             NaN             NaN             NaN             NaN
# 663             100           101.5           118.8             NaN
# 664             NaN             NaN             NaN             NaN
# 665             NaN             NaN             NaN             NaN
#
#                  17              18              19              20  \
# 0               NaN             NaN             NaN             NaN
# 1               NaN             NaN             NaN             NaN
# 2    2009-10 actual  2009-10 target  2008-09 actual  2008-09 target
# 3               NaN             NaN             NaN             NaN
# 4               NaN             NaN             NaN             NaN
# 5               NaN             NaN             NaN             NaN
# 6               NaN             NaN             NaN             NaN
# 7               NaN             NaN             NaN             NaN
# 8               NaN             NaN             NaN             NaN
# 9                 5               5               5               5
# 10               12               6              12              10
# 11              NaN             NaN             NaN             NaN
# 12              NaN             NaN             NaN             NaN
# 13              NaN             NaN             NaN             NaN
# 14               28              20             NaN             NaN
# 15             2060            1800             NaN             NaN
# 16                1               1               1               1
# 17              NaN             NaN             NaN             NaN
# 18              NaN             NaN             NaN             NaN
# 19              NaN             NaN             NaN             NaN
# 20                2               2               2               2
# 21               98              95             NaN             NaN
# 22              NaN             NaN             NaN             NaN
# 23                6               6               6               6
# 24              NaN             NaN             NaN             NaN
# 25              NaN             NaN             NaN             NaN
# 26              100              77              83              30
# 27                3               3               3               3
# 28             54.6              38            44.1            37.2
# 29              NaN             NaN             NaN             NaN
# ..              ...             ...             ...             ...
# 636             NaN             NaN             NaN             NaN
# 637             NaN             NaN             NaN             NaN
# 638             100             100              95             100
# 639             NaN             NaN             NaN             NaN
# 640             NaN             NaN             NaN             NaN
# 641             NaN             NaN             NaN             NaN
# 642             100             100             100             100
# 643              99              99              99              99
# 644              91              85              93              85
# 645             NaN             NaN             NaN             NaN
# 646             NaN             NaN             NaN             NaN
# 647             NaN             NaN             NaN             NaN
# 648              97             100             100             100
# 649             NaN             NaN             NaN             NaN
# 650              88              90              93              80
# 651             NaN             NaN             NaN             NaN
# 652             NaN             NaN             NaN             NaN
# 653              78             100             100             100
# 654              65              80              69              80
# 655             NaN             NaN             NaN             NaN
# 656              68              80              68              80
# 657             NaN             NaN             NaN             NaN
# 658             NaN             NaN             NaN             NaN
# 659             NaN             NaN             NaN             NaN
# 660             100             100             100             100
# 661             NaN             NaN             NaN             NaN
# 662             NaN             NaN             NaN             NaN
# 663             NaN             NaN             NaN             NaN
# 664             NaN             NaN             NaN             NaN
# 665             NaN             NaN             NaN             NaN
#
#                  21     22
# 0               NaN    NaN
# 1               NaN    NaN
# 2    2007-08 actual  Notes
# 3               NaN    NaN
# 4               NaN    NaN
# 5               NaN    NaN
# 6               NaN    NaN
# 7               NaN    NaN
# 8               NaN    NaN
# 9                 5    NaN
# 10               11    NaN
# 11              NaN    NaN
# 12              NaN    NaN
# 13              NaN    NaN
# 14              NaN    NaN
# 15              NaN    NaN
# 16              NaN    NaN
# 17              NaN    NaN
# 18              NaN    NaN
# 19              NaN    NaN
# 20              NaN    NaN
# 21              NaN    NaN
# 22              NaN    NaN
# 23                6    NaN
# 24              NaN    NaN
# 25              NaN    NaN
# 26              NaN    NaN
# 27                7    NaN
# 28             34.3    NaN
# 29              NaN    NaN
# ..              ...    ...
# 636             NaN    NaN
# 637             NaN    NaN
# 638            96.4    NaN
# 639             NaN    NaN
# 640             NaN    NaN
# 641             NaN    NaN
# 642             100    NaN
# 643              99    NaN
# 644              na    NaN
# 645             NaN    NaN
# 646             NaN    NaN
# 647             NaN    NaN
# 648             NaN    NaN
# 649             NaN    NaN
# 650              53    NaN
# 651             NaN    NaN
# 652             NaN    NaN
# 653             100    NaN
# 654              48    NaN
# 655             NaN    NaN
# 656              70    NaN
# 657             NaN    NaN
# 658             NaN    NaN
# 659             NaN    NaN
# 660             100    NaN
# 661             NaN    NaN
# 662             NaN    NaN
# 663             NaN    NaN
# 664             NaN    NaN
# 665             NaN    NaN
#
# [666 rows x 23 columns]

# %%
# Moving around some of the top rows to get useful column labels
col_list = data.iloc[2]
col_list[0] = 'text'

# data = data.dropna(how='all')
data = data.drop(2)
data.columns = col_list

label_col = pd.Series(['' for x in range(len(data.index))])
data.insert(0, 'label', label_col)

data
# Out:
# 2   label                                               text Unit of measure  \
# 0          Department of Economic Development, Jobs, Tran...             NaN
# 1                                                        NaN             NaN
# 3                                       Performance measures             NaN
# 4          More productive, competitive, sustainable and ...             NaN
# 5          The objective creates the conditions for and s...             NaN
# 6                                                Agriculture             NaN
# 7          This output delivers effective and efficient r...             NaN
# 8                                                   Quantity             NaN
# 9          Animal pest, disease and residue control progr...          number
# 10         Applications for intellectual property protection          number
# 11             Client interactions with land health services          number
# 12         The lower 2017-18 target reflects seasonal con...             NaN
# 13         Clients engaged with agriculture productivity ...          number
# 14         Commercial technology licence agreements final...          number
# 15         Farms and related small businesses facing sign...          number
# 16         Genetic improvement of dairy cows achieved thr...        per cent
# 17         Improved agricultural productivity services, p...          number
# 18         Inspections or audits of scientific establishm...          number
# 19         The 2016 17 expected outcome is lower than the...             NaN
# 20          Key bioscience platform technologies established          number
# 21         Known state prohibited weed sites monitored an...        per cent
# 22         New or amended Interstate Certificate Assuranc...          number
# 23         Plant pest, disease and residue control progra...          number
# 24         Projects delivered to support community led ma...          number
# 25         This performance measure is proposed to replac...             NaN
# 26              Post-graduate level/PhD students in training          number
# 27         Strategies developed to overcome identified tr...          number
# 28         Value of co-investment from external (non-stat...       $ million
# 29                                                   Quality             NaN
# 30         Client satisfaction rating of agricultural pro...          number
# ..    ...                                                ...             ...
# 636        Compliance inspections of managed and unmanage...        per cent
# 637        This performance measures replaces the 2016-17...             NaN
# 638        Deliver regulatory services under delegation o...        per cent
# 639        This performance measure renames the existing ...             NaN
# 640        Rail safety audits, compliance inspections and...        per cent
# 641        This performance measure was proposed to be di...             NaN
# 642        Road safety projects completed within agreed s...        per cent
# 643        Road vehicle and driver regulation: currency o...        per cent
# 644        Road vehicle and driver regulation: user satis...        per cent
# 645        The higher 2016-17 expected outcome is a resul...             NaN
# 646                                               Timeliness             NaN
# 647        Applications for bus operator registration and...        per cent
# 648        Applications for rail accreditation and variat...        per cent
# 649        Initiate marine pollution response action with...        per cent
# 650        Multi Purpose Taxi Program: applications asses...        per cent
# 651        New and renewed taxi, hire vehicle and bus dri...        per cent
# 652        This performance measure amends the 2016-17 pe...             NaN
# 653        Road safety programmed works completed within ...        per cent
# 654        Road vehicle and driver regulation: average sp...         seconds
# 655        The 2016-17 expected outcome is higher than th...             NaN
# 656        Road vehicle and driver regulation: customers ...        per cent
# 657        Road vehicle and driver regulation: new and re...        per cent
# 658        This performance measure was proposed to be di...             NaN
# 659        Taxi, hire vehicles and other commercial passe...        per cent
# 660        Transport and marine safety investigations: ac...        per cent
# 661        Transport and marine safety investigations: av...          months
# 662                                                     Cost             NaN
# 663                                        Total output cost       $ million
# 664        The 2016-17 expected outcome is lower than the...             NaN
# 665   NaN  Source: Department of Economic Development, Jo...             NaN
#
# 2   2017-18 target 2016-17 expected outcome 2016-17 target 2015-16 actual  \
# 0              NaN                      NaN            NaN            NaN
# 1              NaN                      NaN            NaN            NaN
# 3              NaN                      NaN            NaN            NaN
# 4              NaN                      NaN            NaN            NaN
# 5              NaN                      NaN            NaN            NaN
# 6              NaN                      NaN            NaN            NaN
# 7              NaN                      NaN            NaN            NaN
# 8              NaN                      NaN            NaN            NaN
# 9                5                        5              5              5
# 10              16                       16             16             16
# 11            1700                     3400           3500           3858
# 12             NaN                      NaN            NaN            NaN
# 13            3910                     3910           3910           5078
# 14              16                       16             16             16
# 15            1700                     1700           1700           1700
# 16               1                        1              1              1
# 17              10                       10             10             10
# 18              25                       23             25             17
# 19             NaN                      NaN            NaN            NaN
# 20               1                        1              1              2
# 21              90                       90             90             99
# 22               2                        2              2              4
# 23               6                        6              6              6
# 24              25                      NaN            NaN            NaN
# 25             NaN                      NaN            NaN            NaN
# 26              65                       65             65             77
# 27               7                        7              7              7
# 28              36                       36             36             38
# 29             NaN                      NaN            NaN            NaN
# 30               8                        8              8              8
# ..             ...                      ...            ...            ...
# 636            100                      NaN            NaN            NaN
# 637            NaN                      NaN            NaN            NaN
# 638            100                      100            100            100
# 639            NaN                      NaN            NaN            NaN
# 640            100                      100            100            100
# 641            NaN                      NaN            NaN            NaN
# 642            100                      100            100            100
# 643             99                       99             99             99
# 644             85                       91             85             90
# 645            NaN                      NaN            NaN            NaN
# 646            NaN                      NaN            NaN            NaN
# 647            100                      100            100            100
# 648            100                      100            100            100
# 649            100                      100            100            100
# 650             97                       97             97             99
# 651             85                       85             85             70
# 652            NaN                      NaN            NaN            NaN
# 653            100                      100            100            100
# 654            240                      290            240            268
# 655            NaN                      NaN            NaN            NaN
# 656             80                       80             80             76
# 657             85                       85             85             88
# 658            NaN                      NaN            NaN            NaN
# 659             85                       85             85            NaN
# 660            100                      100            100            100
# 661             12                       12             12             16
# 662            NaN                      NaN            NaN            NaN
# 663          363.9                    331.3          354.1          286.8
# 664            NaN                      NaN            NaN            NaN
# 665            NaN                      NaN            NaN            NaN
#
# 2   2015-16 target 2014-15 actual 2014-15 target  ...  2011-12 actual  \
# 0              NaN            NaN            NaN  ...             NaN
# 1              NaN            NaN            NaN  ...             NaN
# 3              NaN            NaN            NaN  ...             NaN
# 4              NaN            NaN            NaN  ...             NaN
# 5              NaN            NaN            NaN  ...             NaN
# 6              NaN            NaN            NaN  ...             NaN
# 7              NaN            NaN            NaN  ...             NaN
# 8              NaN            NaN            NaN  ...             NaN
# 9                5              5              5  ...               5
# 10              16              8              8  ...              12
# 11            1700            NaN            NaN  ...             NaN
# 12             NaN            NaN            NaN  ...             NaN
# 13            5100           5464           5500  ...             NaN
# 14              16             16             16  ...              25
# 15            1700           1669           2000  ...            1779
# 16               1              1              1  ...               1
# 17              10              8              8  ...             NaN
# 18              25             25             25  ...             NaN
# 19             NaN            NaN            NaN  ...             NaN
# 20               1              3              1  ...               2
# 21              90             90             90  ...              96
# 22               2            NaN            NaN  ...             NaN
# 23               6              6              6  ...               5
# 24             NaN            NaN            NaN  ...             NaN
# 25             NaN            NaN            NaN  ...             NaN
# 26              65             65             65  ...              87
# 27               7              7              7  ...               3
# 28              36             45             36  ...            51.5
# 29             NaN            NaN            NaN  ...             NaN
# 30               8              9              8  ...             NaN
# ..             ...            ...            ...  ...             ...
# 636            NaN            NaN            NaN  ...             NaN
# 637            NaN            NaN            NaN  ...             NaN
# 638            100            100            100  ...              99
# 639            NaN            NaN            NaN  ...             NaN
# 640            100            NaN            NaN  ...             NaN
# 641            NaN            NaN            NaN  ...             NaN
# 642            100            100            100  ...             100
# 643             99             99             99  ...              99
# 644             85             89             85  ...              89
# 645            NaN            NaN            NaN  ...             NaN
# 646            NaN            NaN            NaN  ...             NaN
# 647            100            100            100  ...             NaN
# 648            100            100            100  ...             100
# 649            100            100            100  ...             100
# 650             97             99             96  ...            96.5
# 651             85             50             85  ...             NaN
# 652            NaN            NaN            NaN  ...             NaN
# 653            100            100            100  ...             100
# 654            240            208            240  ...             NaN
# 655            NaN            NaN            NaN  ...             NaN
# 656             80             81             80  ...              71
# 657             85             75             85  ...             NaN
# 658            NaN            NaN            NaN  ...             NaN
# 659            NaN            NaN            NaN  ...             NaN
# 660            100            100            100  ...             100
# 661             12             14             12  ...             NaN
# 662            NaN            NaN            NaN  ...             NaN
# 663          326.7          280.3          301.1  ...             100
# 664            NaN            NaN            NaN  ...             NaN
# 665            NaN            NaN            NaN  ...             NaN
#
# 2   2011-12 target 2010-11 actual 2010-11 target 2009-10 actual  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# 5              NaN            NaN            NaN            NaN
# 6              NaN            NaN            NaN            NaN
# 7              NaN            NaN            NaN            NaN
# 8              NaN            NaN            NaN            NaN
# 9                5              5              5              5
# 10               8              8              8             12
# 11             NaN            NaN            NaN            NaN
# 12             NaN            NaN            NaN            NaN
# 13             NaN            NaN            NaN            NaN
# 14              20             16             20             28
# 15            2000           1889           1800           2060
# 16               1              1              1              1
# 17             NaN            NaN            NaN            NaN
# 18             NaN            NaN            NaN            NaN
# 19             NaN            NaN            NaN            NaN
# 20               2              3              2              2
# 21              95             97             95             98
# 22             NaN            NaN            NaN            NaN
# 23               6              5              6              6
# 24             NaN            NaN            NaN            NaN
# 25             NaN            NaN            NaN            NaN
# 26              64             97             77            100
# 27               3              3              3              3
# 28            40.5           52.9             37           54.6
# 29             NaN            NaN            NaN            NaN
# 30             NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 636            NaN            NaN            NaN            NaN
# 637            NaN            NaN            NaN            NaN
# 638            100             99            100            100
# 639            NaN            NaN            NaN            NaN
# 640            NaN            NaN            NaN            NaN
# 641            NaN            NaN            NaN            NaN
# 642            100            100            100            100
# 643             99             99             99             99
# 644             85             90             85             91
# 645            NaN            NaN            NaN            NaN
# 646            NaN            NaN            NaN            NaN
# 647            NaN            NaN            NaN            NaN
# 648            100            100            100             97
# 649            100            NaN            NaN            NaN
# 650             95             98             90             88
# 651             nm            NaN            NaN            NaN
# 652            NaN            NaN            NaN            NaN
# 653            100             76            100             78
# 654             80             49             80             65
# 655            NaN            NaN            NaN            NaN
# 656             80             69             80             68
# 657            NaN            NaN            NaN            NaN
# 658            NaN            NaN            NaN            NaN
# 659            NaN            NaN            NaN            NaN
# 660            100            100            100            100
# 661             nm            NaN            NaN            NaN
# 662            NaN            NaN            NaN            NaN
# 663          101.5          118.8            NaN            NaN
# 664            NaN            NaN            NaN            NaN
# 665            NaN            NaN            NaN            NaN
#
# 2   2009-10 target 2008-09 actual 2008-09 target 2007-08 actual Notes
# 0              NaN            NaN            NaN            NaN   NaN
# 1              NaN            NaN            NaN            NaN   NaN
# 3              NaN            NaN            NaN            NaN   NaN
# 4              NaN            NaN            NaN            NaN   NaN
# 5              NaN            NaN            NaN            NaN   NaN
# 6              NaN            NaN            NaN            NaN   NaN
# 7              NaN            NaN            NaN            NaN   NaN
# 8              NaN            NaN            NaN            NaN   NaN
# 9                5              5              5              5   NaN
# 10               6             12             10             11   NaN
# 11             NaN            NaN            NaN            NaN   NaN
# 12             NaN            NaN            NaN            NaN   NaN
# 13             NaN            NaN            NaN            NaN   NaN
# 14              20            NaN            NaN            NaN   NaN
# 15            1800            NaN            NaN            NaN   NaN
# 16               1              1              1            NaN   NaN
# 17             NaN            NaN            NaN            NaN   NaN
# 18             NaN            NaN            NaN            NaN   NaN
# 19             NaN            NaN            NaN            NaN   NaN
# 20               2              2              2            NaN   NaN
# 21              95            NaN            NaN            NaN   NaN
# 22             NaN            NaN            NaN            NaN   NaN
# 23               6              6              6              6   NaN
# 24             NaN            NaN            NaN            NaN   NaN
# 25             NaN            NaN            NaN            NaN   NaN
# 26              77             83             30            NaN   NaN
# 27               3              3              3              7   NaN
# 28              38           44.1           37.2           34.3   NaN
# 29             NaN            NaN            NaN            NaN   NaN
# 30             NaN            NaN            NaN            NaN   NaN
# ..             ...            ...            ...            ...   ...
# 636            NaN            NaN            NaN            NaN   NaN
# 637            NaN            NaN            NaN            NaN   NaN
# 638            100             95            100           96.4   NaN
# 639            NaN            NaN            NaN            NaN   NaN
# 640            NaN            NaN            NaN            NaN   NaN
# 641            NaN            NaN            NaN            NaN   NaN
# 642            100            100            100            100   NaN
# 643             99             99             99             99   NaN
# 644             85             93             85             na   NaN
# 645            NaN            NaN            NaN            NaN   NaN
# 646            NaN            NaN            NaN            NaN   NaN
# 647            NaN            NaN            NaN            NaN   NaN
# 648            100            100            100            NaN   NaN
# 649            NaN            NaN            NaN            NaN   NaN
# 650             90             93             80             53   NaN
# 651            NaN            NaN            NaN            NaN   NaN
# 652            NaN            NaN            NaN            NaN   NaN
# 653            100            100            100            100   NaN
# 654             80             69             80             48   NaN
# 655            NaN            NaN            NaN            NaN   NaN
# 656             80             68             80             70   NaN
# 657            NaN            NaN            NaN            NaN   NaN
# 658            NaN            NaN            NaN            NaN   NaN
# 659            NaN            NaN            NaN            NaN   NaN
# 660            100            100            100            100   NaN
# 661            NaN            NaN            NaN            NaN   NaN
# 662            NaN            NaN            NaN            NaN   NaN
# 663            NaN            NaN            NaN            NaN   NaN
# 664            NaN            NaN            NaN            NaN   NaN
# 665            NaN            NaN            NaN            NaN   NaN
#
# [665 rows x 24 columns]

# %%
data2 = data.copy()
text_labels = data2.iloc[:, 0:3]
# RegEx for filtering out extraneous data labels and notes
irrelevant_regex = re.compile('^performance\smeasures$|new performance measure|expected\soutcome|201[567]-1[678]\starget|sources?:|note:', re.IGNORECASE)
description_regex = re.compile('^this\sperformance\smeasure|^(?:[tT]his|[tT]he)\sobjective|^(?:[tT]his|[tT]he)\soutput', re.IGNORECASE)
cat_regex = re.compile('^Source:')
metric_type_regex = re.compile('^(Quantity|Quality|Timeliness|Cost)$')
text_regex = re.compile('\w+')

def is_irrelevant_text(i, df):
    label = df.iloc[i, 1]
    
    if (type(label) == str and
        (bool(irrelevant_regex.search(label)) or
         bool(description_regex.search(label)) and not is_description(i, df))):
        return True
    
    return False

def is_category_label(i, df):
    for n in range(3, 5):
        if i - 1 >= 0 and type(df.iloc[i - 1, 1]) == str and df.iloc[i - 1, 1] != 'Performance measures':
            return False

        if i + n < len(df):
            label = df.iloc[i + n, 1];

            # If there's an empty cell, between a potential category label and 'Quantity' cell,
            # it's probably not actually a label
            if type(label) != str:
                return False
            # 'Quantity' generally appears at the top of a new table
            if label == 'Quantity' or label == 'Quality':
                if is_category_label(i + 1, df):
                    return False

                source_check = df.iloc[i - 3, 1] if i - 3 >= 0 else ''

                # Extra check in case a category/program doesn't have description
                if n == 3 and type(source_check) == str and bool(cat_regex.search(source_check)):
                    return True
                if n == 4:
                    return True

    return False

def is_program_label(i, df):
    if i + 2 < len(df):
        label = df.iloc[i + 2, 1]

        # If there's an empty cell, between a potential program label and 'Quantity' cell,
        # it's probably not actually a label
        if label == np.nan:
            return False

        # 'Quantity' generally appears at the top of a new table
        if label == 'Quantity' or label == 'Quality':
            return True

    return False

def is_description(i, df):
    if i - 1 >= 0 and (is_category_label(i - 1, df) or is_program_label(i - 1, df)):
        if bool(is_metric_type(i, df)):
            return False
        
        return True
    
    return False

def is_metric_type(i, df):
    label = df.iloc[i, 1]
    
    if type(label) == str and bool(metric_type_regex.search(label)):
        return True
    
    return False

def is_deliverable_label(i, df):
    label = df.iloc[i, 2]

    if type(label) == str and bool(text_regex.search(label)):
        return True
    
    return False

def add_text_label(i, df):
    if type(df.iloc[i, 1]) == str:
        if i == 0:
            return 'department'
        if is_irrelevant_text(i, df):
            return 'irrelevant'
        if is_category_label(i, df):
            return 'category'
        if is_program_label(i, df):
            return 'program'
        if is_description(i, df):
            return 'description'
        if is_metric_type(i, df):
            return 'metric_type'
        if is_deliverable_label(i, df):
            return 'deliverable'
        return 'unknown'
    return np.nan

def add_text_labels(df):
    df_check = df.copy()
    df2 = df.copy()
    df2['label'] = [add_text_label(i, df_check) for i, _ in enumerate(df['text'])]
    
    return df2

data3 = add_text_labels(data2)

data3
# Out:
# 2          label                                               text  \
# 0     department  Department of Economic Development, Jobs, Tran...
# 1            NaN                                                NaN
# 3     irrelevant                               Performance measures
# 4       category  More productive, competitive, sustainable and ...
# 5    description  The objective creates the conditions for and s...
# 6        program                                        Agriculture
# 7    description  This output delivers effective and efficient r...
# 8    metric_type                                           Quantity
# 9    deliverable  Animal pest, disease and residue control progr...
# 10   deliverable  Applications for intellectual property protection
# 11   deliverable      Client interactions with land health services
# 12    irrelevant  The lower 2017-18 target reflects seasonal con...
# 13   deliverable  Clients engaged with agriculture productivity ...
# 14   deliverable  Commercial technology licence agreements final...
# 15   deliverable  Farms and related small businesses facing sign...
# 16   deliverable  Genetic improvement of dairy cows achieved thr...
# 17   deliverable  Improved agricultural productivity services, p...
# 18   deliverable  Inspections or audits of scientific establishm...
# 19    irrelevant  The 2016 17 expected outcome is lower than the...
# 20   deliverable   Key bioscience platform technologies established
# 21   deliverable  Known state prohibited weed sites monitored an...
# 22   deliverable  New or amended Interstate Certificate Assuranc...
# 23   deliverable  Plant pest, disease and residue control progra...
# 24   deliverable  Projects delivered to support community led ma...
# 25    irrelevant  This performance measure is proposed to replac...
# 26   deliverable       Post-graduate level/PhD students in training
# 27       program  Strategies developed to overcome identified tr...
# 28   description  Value of co-investment from external (non-stat...
# 29   metric_type                                            Quality
# 30   deliverable  Client satisfaction rating of agricultural pro...
# ..           ...                                                ...
# 636  deliverable  Compliance inspections of managed and unmanage...
# 637   irrelevant  This performance measures replaces the 2016-17...
# 638  deliverable  Deliver regulatory services under delegation o...
# 639   irrelevant  This performance measure renames the existing ...
# 640  deliverable  Rail safety audits, compliance inspections and...
# 641   irrelevant  This performance measure was proposed to be di...
# 642  deliverable  Road safety projects completed within agreed s...
# 643  deliverable  Road vehicle and driver regulation: currency o...
# 644  deliverable  Road vehicle and driver regulation: user satis...
# 645   irrelevant  The higher 2016-17 expected outcome is a resul...
# 646  metric_type                                         Timeliness
# 647  deliverable  Applications for bus operator registration and...
# 648  deliverable  Applications for rail accreditation and variat...
# 649  deliverable  Initiate marine pollution response action with...
# 650  deliverable  Multi Purpose Taxi Program: applications asses...
# 651  deliverable  New and renewed taxi, hire vehicle and bus dri...
# 652   irrelevant  This performance measure amends the 2016-17 pe...
# 653  deliverable  Road safety programmed works completed within ...
# 654  deliverable  Road vehicle and driver regulation: average sp...
# 655   irrelevant  The 2016-17 expected outcome is higher than th...
# 656  deliverable  Road vehicle and driver regulation: customers ...
# 657  deliverable  Road vehicle and driver regulation: new and re...
# 658   irrelevant  This performance measure was proposed to be di...
# 659  deliverable  Taxi, hire vehicles and other commercial passe...
# 660  deliverable  Transport and marine safety investigations: ac...
# 661  deliverable  Transport and marine safety investigations: av...
# 662  metric_type                                               Cost
# 663  deliverable                                  Total output cost
# 664   irrelevant  The 2016-17 expected outcome is lower than the...
# 665   irrelevant  Source: Department of Economic Development, Jo...
#
# 2   Unit of measure 2017-18 target 2016-17 expected outcome 2016-17 target  \
# 0               NaN            NaN                      NaN            NaN
# 1               NaN            NaN                      NaN            NaN
# 3               NaN            NaN                      NaN            NaN
# 4               NaN            NaN                      NaN            NaN
# 5               NaN            NaN                      NaN            NaN
# 6               NaN            NaN                      NaN            NaN
# 7               NaN            NaN                      NaN            NaN
# 8               NaN            NaN                      NaN            NaN
# 9            number              5                        5              5
# 10           number             16                       16             16
# 11           number           1700                     3400           3500
# 12              NaN            NaN                      NaN            NaN
# 13           number           3910                     3910           3910
# 14           number             16                       16             16
# 15           number           1700                     1700           1700
# 16         per cent              1                        1              1
# 17           number             10                       10             10
# 18           number             25                       23             25
# 19              NaN            NaN                      NaN            NaN
# 20           number              1                        1              1
# 21         per cent             90                       90             90
# 22           number              2                        2              2
# 23           number              6                        6              6
# 24           number             25                      NaN            NaN
# 25              NaN            NaN                      NaN            NaN
# 26           number             65                       65             65
# 27           number              7                        7              7
# 28        $ million             36                       36             36
# 29              NaN            NaN                      NaN            NaN
# 30           number              8                        8              8
# ..              ...            ...                      ...            ...
# 636        per cent            100                      NaN            NaN
# 637             NaN            NaN                      NaN            NaN
# 638        per cent            100                      100            100
# 639             NaN            NaN                      NaN            NaN
# 640        per cent            100                      100            100
# 641             NaN            NaN                      NaN            NaN
# 642        per cent            100                      100            100
# 643        per cent             99                       99             99
# 644        per cent             85                       91             85
# 645             NaN            NaN                      NaN            NaN
# 646             NaN            NaN                      NaN            NaN
# 647        per cent            100                      100            100
# 648        per cent            100                      100            100
# 649        per cent            100                      100            100
# 650        per cent             97                       97             97
# 651        per cent             85                       85             85
# 652             NaN            NaN                      NaN            NaN
# 653        per cent            100                      100            100
# 654         seconds            240                      290            240
# 655             NaN            NaN                      NaN            NaN
# 656        per cent             80                       80             80
# 657        per cent             85                       85             85
# 658             NaN            NaN                      NaN            NaN
# 659        per cent             85                       85             85
# 660        per cent            100                      100            100
# 661          months             12                       12             12
# 662             NaN            NaN                      NaN            NaN
# 663       $ million          363.9                    331.3          354.1
# 664             NaN            NaN                      NaN            NaN
# 665             NaN            NaN                      NaN            NaN
#
# 2   2015-16 actual 2015-16 target 2014-15 actual 2014-15 target  ...   \
# 0              NaN            NaN            NaN            NaN  ...
# 1              NaN            NaN            NaN            NaN  ...
# 3              NaN            NaN            NaN            NaN  ...
# 4              NaN            NaN            NaN            NaN  ...
# 5              NaN            NaN            NaN            NaN  ...
# 6              NaN            NaN            NaN            NaN  ...
# 7              NaN            NaN            NaN            NaN  ...
# 8              NaN            NaN            NaN            NaN  ...
# 9                5              5              5              5  ...
# 10              16             16              8              8  ...
# 11            3858           1700            NaN            NaN  ...
# 12             NaN            NaN            NaN            NaN  ...
# 13            5078           5100           5464           5500  ...
# 14              16             16             16             16  ...
# 15            1700           1700           1669           2000  ...
# 16               1              1              1              1  ...
# 17              10             10              8              8  ...
# 18              17             25             25             25  ...
# 19             NaN            NaN            NaN            NaN  ...
# 20               2              1              3              1  ...
# 21              99             90             90             90  ...
# 22               4              2            NaN            NaN  ...
# 23               6              6              6              6  ...
# 24             NaN            NaN            NaN            NaN  ...
# 25             NaN            NaN            NaN            NaN  ...
# 26              77             65             65             65  ...
# 27               7              7              7              7  ...
# 28              38             36             45             36  ...
# 29             NaN            NaN            NaN            NaN  ...
# 30               8              8              9              8  ...
# ..             ...            ...            ...            ...  ...
# 636            NaN            NaN            NaN            NaN  ...
# 637            NaN            NaN            NaN            NaN  ...
# 638            100            100            100            100  ...
# 639            NaN            NaN            NaN            NaN  ...
# 640            100            100            NaN            NaN  ...
# 641            NaN            NaN            NaN            NaN  ...
# 642            100            100            100            100  ...
# 643             99             99             99             99  ...
# 644             90             85             89             85  ...
# 645            NaN            NaN            NaN            NaN  ...
# 646            NaN            NaN            NaN            NaN  ...
# 647            100            100            100            100  ...
# 648            100            100            100            100  ...
# 649            100            100            100            100  ...
# 650             99             97             99             96  ...
# 651             70             85             50             85  ...
# 652            NaN            NaN            NaN            NaN  ...
# 653            100            100            100            100  ...
# 654            268            240            208            240  ...
# 655            NaN            NaN            NaN            NaN  ...
# 656             76             80             81             80  ...
# 657             88             85             75             85  ...
# 658            NaN            NaN            NaN            NaN  ...
# 659            NaN            NaN            NaN            NaN  ...
# 660            100            100            100            100  ...
# 661             16             12             14             12  ...
# 662            NaN            NaN            NaN            NaN  ...
# 663          286.8          326.7          280.3          301.1  ...
# 664            NaN            NaN            NaN            NaN  ...
# 665            NaN            NaN            NaN            NaN  ...
#
# 2   2011-12 actual 2011-12 target 2010-11 actual 2010-11 target  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# 5              NaN            NaN            NaN            NaN
# 6              NaN            NaN            NaN            NaN
# 7              NaN            NaN            NaN            NaN
# 8              NaN            NaN            NaN            NaN
# 9                5              5              5              5
# 10              12              8              8              8
# 11             NaN            NaN            NaN            NaN
# 12             NaN            NaN            NaN            NaN
# 13             NaN            NaN            NaN            NaN
# 14              25             20             16             20
# 15            1779           2000           1889           1800
# 16               1              1              1              1
# 17             NaN            NaN            NaN            NaN
# 18             NaN            NaN            NaN            NaN
# 19             NaN            NaN            NaN            NaN
# 20               2              2              3              2
# 21              96             95             97             95
# 22             NaN            NaN            NaN            NaN
# 23               5              6              5              6
# 24             NaN            NaN            NaN            NaN
# 25             NaN            NaN            NaN            NaN
# 26              87             64             97             77
# 27               3              3              3              3
# 28            51.5           40.5           52.9             37
# 29             NaN            NaN            NaN            NaN
# 30             NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 636            NaN            NaN            NaN            NaN
# 637            NaN            NaN            NaN            NaN
# 638             99            100             99            100
# 639            NaN            NaN            NaN            NaN
# 640            NaN            NaN            NaN            NaN
# 641            NaN            NaN            NaN            NaN
# 642            100            100            100            100
# 643             99             99             99             99
# 644             89             85             90             85
# 645            NaN            NaN            NaN            NaN
# 646            NaN            NaN            NaN            NaN
# 647            NaN            NaN            NaN            NaN
# 648            100            100            100            100
# 649            100            100            NaN            NaN
# 650           96.5             95             98             90
# 651            NaN             nm            NaN            NaN
# 652            NaN            NaN            NaN            NaN
# 653            100            100             76            100
# 654            NaN             80             49             80
# 655            NaN            NaN            NaN            NaN
# 656             71             80             69             80
# 657            NaN            NaN            NaN            NaN
# 658            NaN            NaN            NaN            NaN
# 659            NaN            NaN            NaN            NaN
# 660            100            100            100            100
# 661            NaN             nm            NaN            NaN
# 662            NaN            NaN            NaN            NaN
# 663            100          101.5          118.8            NaN
# 664            NaN            NaN            NaN            NaN
# 665            NaN            NaN            NaN            NaN
#
# 2   2009-10 actual 2009-10 target 2008-09 actual 2008-09 target  \
# 0              NaN            NaN            NaN            NaN
# 1              NaN            NaN            NaN            NaN
# 3              NaN            NaN            NaN            NaN
# 4              NaN            NaN            NaN            NaN
# 5              NaN            NaN            NaN            NaN
# 6              NaN            NaN            NaN            NaN
# 7              NaN            NaN            NaN            NaN
# 8              NaN            NaN            NaN            NaN
# 9                5              5              5              5
# 10              12              6             12             10
# 11             NaN            NaN            NaN            NaN
# 12             NaN            NaN            NaN            NaN
# 13             NaN            NaN            NaN            NaN
# 14              28             20            NaN            NaN
# 15            2060           1800            NaN            NaN
# 16               1              1              1              1
# 17             NaN            NaN            NaN            NaN
# 18             NaN            NaN            NaN            NaN
# 19             NaN            NaN            NaN            NaN
# 20               2              2              2              2
# 21              98             95            NaN            NaN
# 22             NaN            NaN            NaN            NaN
# 23               6              6              6              6
# 24             NaN            NaN            NaN            NaN
# 25             NaN            NaN            NaN            NaN
# 26             100             77             83             30
# 27               3              3              3              3
# 28            54.6             38           44.1           37.2
# 29             NaN            NaN            NaN            NaN
# 30             NaN            NaN            NaN            NaN
# ..             ...            ...            ...            ...
# 636            NaN            NaN            NaN            NaN
# 637            NaN            NaN            NaN            NaN
# 638            100            100             95            100
# 639            NaN            NaN            NaN            NaN
# 640            NaN            NaN            NaN            NaN
# 641            NaN            NaN            NaN            NaN
# 642            100            100            100            100
# 643             99             99             99             99
# 644             91             85             93             85
# 645            NaN            NaN            NaN            NaN
# 646            NaN            NaN            NaN            NaN
# 647            NaN            NaN            NaN            NaN
# 648             97            100            100            100
# 649            NaN            NaN            NaN            NaN
# 650             88             90             93             80
# 651            NaN            NaN            NaN            NaN
# 652            NaN            NaN            NaN            NaN
# 653             78            100            100            100
# 654             65             80             69             80
# 655            NaN            NaN            NaN            NaN
# 656             68             80             68             80
# 657            NaN            NaN            NaN            NaN
# 658            NaN            NaN            NaN            NaN
# 659            NaN            NaN            NaN            NaN
# 660            100            100            100            100
# 661            NaN            NaN            NaN            NaN
# 662            NaN            NaN            NaN            NaN
# 663            NaN            NaN            NaN            NaN
# 664            NaN            NaN            NaN            NaN
# 665            NaN            NaN            NaN            NaN
#
# 2   2007-08 actual Notes
# 0              NaN   NaN
# 1              NaN   NaN
# 3              NaN   NaN
# 4              NaN   NaN
# 5              NaN   NaN
# 6              NaN   NaN
# 7              NaN   NaN
# 8              NaN   NaN
# 9                5   NaN
# 10              11   NaN
# 11             NaN   NaN
# 12             NaN   NaN
# 13             NaN   NaN
# 14             NaN   NaN
# 15             NaN   NaN
# 16             NaN   NaN
# 17             NaN   NaN
# 18             NaN   NaN
# 19             NaN   NaN
# 20             NaN   NaN
# 21             NaN   NaN
# 22             NaN   NaN
# 23               6   NaN
# 24             NaN   NaN
# 25             NaN   NaN
# 26             NaN   NaN
# 27               7   NaN
# 28            34.3   NaN
# 29             NaN   NaN
# 30             NaN   NaN
# ..             ...   ...
# 636            NaN   NaN
# 637            NaN   NaN
# 638           96.4   NaN
# 639            NaN   NaN
# 640            NaN   NaN
# 641            NaN   NaN
# 642            100   NaN
# 643             99   NaN
# 644             na   NaN
# 645            NaN   NaN
# 646            NaN   NaN
# 647            NaN   NaN
# 648            NaN   NaN
# 649            NaN   NaN
# 650             53   NaN
# 651            NaN   NaN
# 652            NaN   NaN
# 653            100   NaN
# 654             48   NaN
# 655            NaN   NaN
# 656             70   NaN
# 657            NaN   NaN
# 658            NaN   NaN
# 659            NaN   NaN
# 660            100   NaN
# 661            NaN   NaN
# 662            NaN   NaN
# 663            NaN   NaN
# 664            NaN   NaN
# 665            NaN   NaN
#
# [665 rows x 24 columns]

# %%
data4 = data3[data3['label'] == 'unknown']

data4
# Out:
# 2      label                                               text  \
# 0    unknown  Department of Economic Development, Jobs, Tran...
# 216  unknown  The higher outcome for the 2015-16 financial y...
# 368  unknown  Metropolitan buses are on-time when services d...
# 370  unknown  Regional buses are on-time when services depar...
# 406  unknown  The target for 2017-18 is subject to Commonwea...
# 563  unknown  Metropolitan trains are considered on time if ...
# 594  unknown  Trams are on-time when services are no more th...
#
# 2   Unit of measure 2017-18 target 2016-17 expected outcome 2016-17 target  \
# 0               NaN            NaN                      NaN            NaN
# 216             NaN            NaN                      NaN            NaN
# 368             NaN            NaN                      NaN            NaN
# 370             NaN            NaN                      NaN            NaN
# 406             NaN            NaN                      NaN            NaN
# 563             NaN            NaN                      NaN            NaN
# 594             NaN            NaN                      NaN            NaN
#
# 2   2015-16 actual 2015-16 target 2014-15 actual 2014-15 target  ...   \
# 0              NaN            NaN            NaN            NaN  ...
# 216            NaN            NaN            NaN            NaN  ...
# 368            NaN            NaN            NaN            NaN  ...
# 370            NaN            NaN            NaN            NaN  ...
# 406            NaN            NaN            NaN            NaN  ...
# 563            NaN            NaN            NaN            NaN  ...
# 594            NaN            NaN            NaN            NaN  ...
#
# 2   2011-12 actual 2011-12 target 2010-11 actual 2010-11 target  \
# 0              NaN            NaN            NaN            NaN
# 216            NaN            NaN            NaN            NaN
# 368            NaN            NaN            NaN            NaN
# 370            NaN            NaN            NaN            NaN
# 406            NaN            NaN            NaN            NaN
# 563            NaN            NaN            NaN            NaN
# 594            NaN            NaN            NaN            NaN
#
# 2   2009-10 actual 2009-10 target 2008-09 actual 2008-09 target  \
# 0              NaN            NaN            NaN            NaN
# 216            NaN            NaN            NaN            NaN
# 368            NaN            NaN            NaN            NaN
# 370            NaN            NaN            NaN            NaN
# 406            NaN            NaN            NaN            NaN
# 563            NaN            NaN            NaN            NaN
# 594            NaN            NaN            NaN            NaN
#
# 2   2007-08 actual Notes
# 0              NaN   NaN
# 216            NaN   NaN
# 368            NaN   NaN
# 370            NaN   NaN
# 406            NaN   NaN
# 563            NaN   NaN
# 594            NaN   NaN
#
# [7 rows x 24 columns]

# %%
import pandas as pd
import os
import re
import numpy as np


def load_file(file_name='Department-of-Economic-Development-Jobs-Transport-and-Resources-Output-Performance-Measures-2017-18.xlsx'):
    # Load the raw Excel file
    file_path = os.path.abspath(os.path.join(os.getcwd(), '../raw_data/budgets/', file_name))
    df = pd.read_excel(file_path, header=None, thousands=' ')

    return df


# Clean up the numbers with converter function
def clean_numbers(df):
    return df.applymap(lambda x: converter(x))


character_regex = re.compile('[\s,<>]')


def converter(cell_value):
    if type(cell_value) == str:
        # 'nm' is the VIC government's NaN
        if cell_value == 'nm':
            return np.nan

        # Some numbers are presented as ranges with '-'. We just average the range to get a useable value.
        if '-' in cell_value:
            numbers = cell_value.split('-')

            try:
                return np.mean(float(numbers[0]), float(numbers[1]))
            except (ValueError, TypeError):
                return cell_value

        # Remove spaces and symbols
        if bool(re.search(character_regex, cell_value)):
            number = re.sub(character_regex, '', cell_value)

            try:
                return float(number)
            except ValueError:
                return cell_value

    return cell_value


def organize_rows(df):
    # Moving around some of the top rows to get useful column labels
    col_list = df.iloc[2]
    col_list[0] = 'text'

    new_df = df.drop(2)
    new_df.columns = col_list

    return new_df


def add_text_labels(df):
    new_df = df.copy()
    new_df['label'] = [add_text_label(i, df) for i, _ in enumerate(df['text'])]

    return new_df


def add_text_label(i, df):
    if type(df.iloc[i, 0]) == str:
        if i == 0:
            return 'department'
        if is_irrelevant_text(i, df):
            return 'irrelevant'
        if is_deliverable_label(i, df):
            return 'deliverable'
        if is_category_label(i, df):
            return 'category'
        if is_program_label(i, df):
            return 'program'
        if is_description(i, df):
            return 'description'
        if is_metric_type(i, df):
            return 'metric_type'
        return 'unknown'
    return np.nan


# RegEx for filtering out extraneous data labels and notes
irrelevant_regex = re.compile('^performance\smeasures$|new performance measure|expected\soutcome|201[567]-1[678]\starget|sources?:|note:', re.IGNORECASE)
description_regex = re.compile('^this\sperformance\smeasure|^(?:[tT]his|[tT]he)\sobjective|^(?:[tT]his|[tT]he)\soutput', re.IGNORECASE)
cat_regex = re.compile('^Source:')
metric_type_regex = re.compile('^(Quantity|Quality|Timeliness|Cost)$')
text_regex = re.compile('\w+')


def is_irrelevant_text(i, df):
    label = df.iloc[i, 0]

    if (type(label) == str and
        (bool(irrelevant_regex.search(label)) or
         bool(description_regex.search(label)) and not is_description(i, df))):
        return True

    return False


def is_deliverable_label(i, df):
    label = df.iloc[i, 1]

    if type(label) == str and bool(text_regex.search(label)):
        return True

    return False


def is_category_label(i, df):
    for n in range(3, 5):
        if i - 1 >= 0 and type(df.iloc[i - 1, 0]) == str and df.iloc[i - 1, 0] != 'Performance measures':
            return False

        if i + n < len(df):
            label = df.iloc[i + n, 0]

            # If there's an empty cell, between a potential category label and 'Quantity' cell,
            # it's probably not actually a label
            if type(label) != str:
                return False
            # 'Quantity' generally appears at the top of a new table
            if label == 'Quantity' or label == 'Quality':
                if is_category_label(i + 1, df):
                    return False

                source_check = df.iloc[i - 3, 0] if i - 3 >= 0 else ''

                # Extra check in case a category/program doesn't have description
                if n == 3 and type(source_check) == str and bool(cat_regex.search(source_check)):
                    return True
                if n == 4:
                    return True

    return False


def is_program_label(i, df):
    if i + 2 < len(df):
        label = df.iloc[i + 2, 0]

        # If there's an empty cell, between a potential program label and 'Quantity' cell,
        # it's probably not actually a label
        if label == np.nan:
            return False

        # 'Quantity' generally appears at the top of a new table
        if label == 'Quantity' or label == 'Quality':
            return True

    return False


def is_description(i, df):
    if i - 1 >= 0 and (is_category_label(i - 1, df) or is_program_label(i - 1, df)):
        if bool(is_metric_type(i, df)):
            return False

        return True

    return False


def is_metric_type(i, df):
    label = df.iloc[i, 0]

    if type(label) == str and bool(metric_type_regex.search(label)):
        return True

    return False


def main():
    df = load_file()
    df2 = clean_numbers(df)
    df3 = organize_rows(df2)
    df4 = add_text_labels(df3)

    return df4


my_df = main()

# %%
my_df[my_df['label'] == 'program']
# Out:
# 2                                                 text Unit of measure  \
# 6                                          Agriculture             NaN
# 51                                           Resources             NaN
# 74   Sustainably Manage Fish, Game and Forest Resou...             NaN
# 112  Creative Industries Access, Development and In...             NaN
# 141             Creative Industries Portfolio Agencies             NaN
# 176             Cultural Infrastructure and Facilities             NaN
# 193  Tourism, Major Events and International Education             NaN
# 226                               Industrial Relations             NaN
# 238                 Industry and Enterprise Innovation             NaN
# 262                                Jobs and Investment             NaN
# 295                                     Major Projects             NaN
# 311                              Regional Development              NaN
# 326                                              Trade             NaN
# 343                                       Bus Services             NaN
# 376                               Integrated Transport             NaN
# 391                    Port and Freight Network Access             NaN
# 413                              Road Asset Management             NaN
# 455          Road Operations and Network Improvements              NaN
# 491                    Taxi and Hire Vehicle Services              NaN
# 525                                     Train Services             NaN
# 571                                      Tram Services             NaN
# 600  Transport Safety, Security and Emergency Manag...             NaN
#
# 2   2017-18 target 2016-17 expected outcome 2016-17 target 2015-16 actual  \
# 6              NaN                      NaN            NaN            NaN
# 51             NaN                      NaN            NaN            NaN
# 74             NaN                      NaN            NaN            NaN
# 112            NaN                      NaN            NaN            NaN
# 141            NaN                      NaN            NaN            NaN
# 176            NaN                      NaN            NaN            NaN
# 193            NaN                      NaN            NaN            NaN
# 226            NaN                      NaN            NaN            NaN
# 238            NaN                      NaN            NaN            NaN
# 262            NaN                      NaN            NaN            NaN
# 295            NaN                      NaN            NaN            NaN
# 311            NaN                      NaN            NaN            NaN
# 326            NaN                      NaN            NaN            NaN
# 343            NaN                      NaN            NaN            NaN
# 376            NaN                      NaN            NaN            NaN
# 391            NaN                      NaN            NaN            NaN
# 413            NaN                      NaN            NaN            NaN
# 455            NaN                      NaN            NaN            NaN
# 491            NaN                      NaN            NaN            NaN
# 525            NaN                      NaN            NaN            NaN
# 571            NaN                      NaN            NaN            NaN
# 600            NaN                      NaN            NaN            NaN
#
# 2   2015-16 target 2014-15 actual 2014-15 target 2013-14 actual   ...     \
# 6              NaN            NaN            NaN            NaN   ...
# 51             NaN            NaN            NaN            NaN   ...
# 74             NaN            NaN            NaN            NaN   ...
# 112            NaN            NaN            NaN            NaN   ...
# 141            NaN            NaN            NaN            NaN   ...
# 176            NaN            NaN            NaN            NaN   ...
# 193            NaN            NaN            NaN            NaN   ...
# 226            NaN            NaN            NaN            NaN   ...
# 238            NaN            NaN            NaN            NaN   ...
# 262            NaN            NaN            NaN            NaN   ...
# 295            NaN            NaN            NaN            NaN   ...
# 311            NaN            NaN            NaN            NaN   ...
# 326            NaN            NaN            NaN            NaN   ...
# 343            NaN            NaN            NaN            NaN   ...
# 376            NaN            NaN            NaN            NaN   ...
# 391            NaN            NaN            NaN            NaN   ...
# 413            NaN            NaN            NaN            NaN   ...
# 455            NaN            NaN            NaN            NaN   ...
# 491            NaN            NaN            NaN            NaN   ...
# 525            NaN            NaN            NaN            NaN   ...
# 571            NaN            NaN            NaN            NaN   ...
# 600            NaN            NaN            NaN            NaN   ...
#
# 2   2011-12 target 2010-11 actual 2010-11 target 2009-10 actual  \
# 6              NaN            NaN            NaN            NaN
# 51             NaN            NaN            NaN            NaN
# 74             NaN            NaN            NaN            NaN
# 112            NaN            NaN            NaN            NaN
# 141            NaN            NaN            NaN            NaN
# 176            NaN            NaN            NaN            NaN
# 193            NaN            NaN            NaN            NaN
# 226            NaN            NaN            NaN            NaN
# 238            NaN            NaN            NaN            NaN
# 262            NaN            NaN            NaN            NaN
# 295            NaN            NaN            NaN            NaN
# 311            NaN            NaN            NaN            NaN
# 326            NaN            NaN            NaN            NaN
# 343            NaN            NaN            NaN            NaN
# 376            NaN            NaN            NaN            NaN
# 391            NaN            NaN            NaN            NaN
# 413            NaN            NaN            NaN            NaN
# 455            NaN            NaN            NaN            NaN
# 491            NaN            NaN            NaN            NaN
# 525            NaN            NaN            NaN            NaN
# 571            NaN            NaN            NaN            NaN
# 600            NaN            NaN            NaN            NaN
#
# 2   2009-10 target 2008-09 actual 2008-09 target 2007-08 actual Notes    label
# 6              NaN            NaN            NaN            NaN   NaN  program
# 51             NaN            NaN            NaN            NaN   NaN  program
# 74             NaN            NaN            NaN            NaN   NaN  program
# 112            NaN            NaN            NaN            NaN   NaN  program
# 141            NaN            NaN            NaN            NaN   NaN  program
# 176            NaN            NaN            NaN            NaN   NaN  program
# 193            NaN            NaN            NaN            NaN   NaN  program
# 226            NaN            NaN            NaN            NaN   NaN  program
# 238            NaN            NaN            NaN            NaN   NaN  program
# 262            NaN            NaN            NaN            NaN   NaN  program
# 295            NaN            NaN            NaN            NaN   NaN  program
# 311            NaN            NaN            NaN            NaN   NaN  program
# 326            NaN            NaN            NaN            NaN   NaN  program
# 343            NaN            NaN            NaN            NaN   NaN  program
# 376            NaN            NaN            NaN            NaN   NaN  program
# 391            NaN            NaN            NaN            NaN   NaN  program
# 413            NaN            NaN            NaN            NaN   NaN  program
# 455            NaN            NaN            NaN            NaN   NaN  program
# 491            NaN            NaN            NaN            NaN   NaN  program
# 525            NaN            NaN            NaN            NaN   NaN  program
# 571            NaN            NaN            NaN            NaN   NaN  program
# 600            NaN            NaN            NaN            NaN   NaN  program
#
# [22 rows x 24 columns]

# %%
print(
    len(my_df[my_df['label'] == 'irrelevant']),
    len(my_df[my_df['label'] == 'deliverable']),
    len(my_df[my_df['label'] == 'category']),
    len(my_df[my_df['label'] == 'program']),
    len(my_df[my_df['label'] == 'description']),
    len(my_df[my_df['label'] == 'metric_type'])
)
# Out:
# 191 307 4 22 27 82

# %%
counts = [191, 307, 4, 22, 27, 82]
for num in counts:
    print(665/(len(counts)*num))
# Out:
# 0.5802792321116929
# 0.36102062975027144
# 27.708333333333332
# 5.037878787878788
# 4.104938271604938
# 1.3516260162601625
